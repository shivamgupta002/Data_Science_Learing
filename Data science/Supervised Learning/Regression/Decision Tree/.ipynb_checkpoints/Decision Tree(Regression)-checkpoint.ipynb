# %% [markdown]
# ### Decison tree use where data is not linear

# %% [markdown]
# we are test using linear dataset

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../../../../data/Salary_Data.csv")
df.head(5)
# Out:
#     Age  Experience  Salary
# 0  21.0         1.1   39343
# 1  21.5         1.3   46205
# 2  21.7         1.5   37731
# 3  22.0         2.0   43525
# 4  22.2         2.2   39891

# %%
df.isnull().sum()
# Out:
# Age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
sns.pairplot(data=df)
plt.show()

# %%
x=df.iloc[:,:-1]
y=df["Experience"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree

# %%
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt.score(x_test,y_test)*100
# Out:
# 98.95153415223314

# %%
dt.score(x_train,y_train)*100 ## check for overfitting (if the difference is more than overfitting occur)
# Out:
# 100.0

# %%
plt.figure(figsize=(15,6))
plot_tree(dt)
plt.show()
