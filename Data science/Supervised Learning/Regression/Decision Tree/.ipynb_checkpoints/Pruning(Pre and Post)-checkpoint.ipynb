# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
df=pd.read_csv("../../../../data/Social_Network_Ads.csv")
df.head(5)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
sns.scatterplot(x="Age",y="EstimatedSalary",data=df,hue="Purchased")
plt.show()

# %%
x=df.iloc[:,:-1]
y=df["Purchased"]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc.fit(x)
x=pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
x.head(5)
# Out:
#         Age  EstimatedSalary
# 0 -1.781797        -1.490046
# 1 -0.253587        -1.460681
# 2 -1.113206        -0.785290
# 3 -1.017692        -0.374182
# 4 -1.781797         0.183751

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(x_test,y_test)*100
# Out:
# 83.75

# %%
dt.score(x_train,y_train)*100
# Out:
# 99.6875

# %%
dt1=DecisionTreeClassifier(max_depth=5)
dt1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
dt1.score(x_test,y_test)*100
# Out:
# 90.0

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dt1)
plt.show()
# Out:
# F:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(20,10))
plot_tree(dt1)
# plt.savefig("Tree.jpg") ## Use for save figure in gallery
plt.show()

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dt)
plt.show()
# Out:
# F:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
dt.predict([[19,19000]])
# Out:
# F:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(20,10))
plot_tree(dt)
# plt.savefig("Tree.jpg") ## Use for save figure in gallery
plt.show()

# %%
dt2=DecisionTreeClassifier(criterion="entropy")
dt2.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dt2.score(x_test,y_test)*100
# Out:
# 83.75

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dt2)
plt.show()
# Out:
# F:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Post Puring

# %%
for i in range(1,20):
    dt3=DecisionTreeClassifier(max_depth=i)
    dt3.fit(x_train,y_train)
    print(i,dt3.score(x_train,y_train)*100,dt3.score(x_test,y_test)*100)
# Out:
# 1 82.1875 90.0
# 2 91.875 91.25
# 3 91.875 91.25
# 4 93.125 91.25
# 5 93.4375 90.0
# 6 95.0 86.25
# 7 96.875 85.0
# 8 97.1875 85.0
# 9 98.125 85.0
# 10 98.4375 85.0
# 11 99.0625 83.75
# 12 99.375 83.75
# 13 99.6875 83.75
# 14 99.6875 83.75
# 15 99.6875 83.75
# 16 99.6875 83.75
# 17 99.6875 83.75
# 18 99.6875 83.75
# 19 99.6875 83.75

# %% [markdown]
# ### Hence max_Depth will be good for 2 and 3 because in this differnce between score of train and test data will be less
