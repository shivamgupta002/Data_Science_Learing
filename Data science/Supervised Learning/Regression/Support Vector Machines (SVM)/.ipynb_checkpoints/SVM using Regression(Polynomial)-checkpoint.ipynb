# %% [markdown]
# ## For Polynomial Data

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../../../../data/Salary_Level_update.csv")
df.head(5)
# Out:
#    Level    Salary
# 0      1   45000.0
# 1      2   50000.0
# 2      3   60000.0
# 3      4   80000.0
# 4      5  110000.0

# %%
df.isnull().sum()
# Out:
# Level     0
# Salary    0
# dtype: int64

# %%
plt.figure(figsize=(6,3))
sns.scatterplot(x="Level",y="Salary",data=df)
plt.show()

# %%
x=df[["Level"]] ## machine learning algorith work on 2-d array
y=df[["Salary"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=40,test_size=0.2)

# %%
from sklearn.svm import SVR ## SVR is Support Vector Regression

# %%
### kernel= "linear","rbf","poly","sigmoid","precomputed" 

sv=SVR() ## By default rbf used
sv.fit(x_train,y_train)
# Out:
# F:\python\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
sv1=SVR(kernel="linear")
sv1.fit(x_train,y_train)
# Out:
# F:\python\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='linear')

# %%
sv2=SVR(kernel="poly") 
sv2.fit(x_train,y_train)
# Out:
# F:\python\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='poly')

# %%
sv3=SVR(kernel="sigmoid") 
sv3.fit(x_train,y_train)
# Out:
# F:\python\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='sigmoid')

# %%
print("Testing Score")

print("rbf",sv.score(x_test,y_test)*100)
print("linear",sv1.score(x_test,y_test)*100)
print("poly",sv2.score(x_test,y_test)*100)
print("sigmoid",sv3.score(x_test,y_test)*100)
# Out:
# Testing Score
# rbf -14.413402789332475
# linear -13.533994617389244
# poly -14.01679287704285
# sigmoid -14.415754575694972

# %%
print("Training Score")

print("rbf",sv.score(x_train,y_train)*100)
print("linear",sv1.score(x_train,y_train)*100)
print("poly",sv2.score(x_train,y_train)*100)
print("sigmoid",sv3.score(x_train,y_train)*100)
# Out:
# Training Score
# rbf -0.7268104799582176
# linear 0.08507005287047287
# poly 0.10345089151022613
# sigmoid -0.7290169921506662

# %%
### Linear Graph 
sns.scatterplot(x="Level",y="Salary",data=df)
plt.plot(df["Level"],sv1.predict(x),color="red")
plt.show()

# %%
### rbf Graph 
sns.scatterplot(x="Level",y="Salary",data=df)
plt.plot(df["Level"],sv.predict(x),color="red")
plt.show()

# %%
### poly Graph
sns.scatterplot(x="Level",y="Salary",data=df)
plt.plot(df["Level"],sv2.predict(x),color="red")
plt.show()

# %%
### sigmoid Grpah
sns.scatterplot(x="Level",y="Salary",data=df)
plt.plot(df["Level"],sv3.predict(x),color="red")
plt.show()

# %%
sns.scatterplot(x="Level",y="Salary",data=df)
plt.plot(df["Level"],sv.predict(x),color="red")
plt.plot(df["Level"],sv1.predict(x),color="black")
plt.plot(df["Level"],sv2.predict(x),color="yellow")
plt.plot(df["Level"],sv3.predict(x),color="blue")
plt.show()

# %% [markdown]
# ### Use Polynomail Regression for this
