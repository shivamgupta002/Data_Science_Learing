# %% [markdown]
# ### For polynomial  Model

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
df=pd.read_csv("../../../../data/placement_update.csv")
df.head(5)
# Out:
#    cgpa  score  placed
# 0  7.19     26       1
# 1  7.46     38       1
# 2  7.54     40       1
# 3  6.42      8       1
# 4  7.23     17       0

# %%
df.isnull().sum()
# Out:
# cgpa      0
# score     0
# placed    0
# dtype: int64

# %%
plt.figure(figsize=(7,3))
sns.scatterplot(x="cgpa",y="score",data=df,hue="placed")
plt.show()

# %%
x=df.iloc[:,:-1]
y=df["placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=15,test_size=0.2)

# %%
from sklearn.svm import SVC ## SVC-> Support vector classifier

# %%
sv=SVC(kernel="linear")
sv.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
sv.score(x_test,y_test)*100
# Out:
# 50.5

# %%
sv.score(x_train,y_train)*100
# Out:
# 51.24999999999999

# %% [markdown]
# Here the differnce between training and testing datset will be more so there will be some error.
# we can change number of random state

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=sv)
plt.show()
# Out:
# F:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### We can chanage kernel also to get better answer

# %%
### kernel= "linear","rbf","poly","sigmoid","precomputed" 
## precomputed is used where only 0 and 1 are used
sv=SVC(kernel="linear")
sv.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
sv1=SVC(kernel="poly") 
sv1.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
sv2=SVC(kernel="sigmoid") 
sv2.fit(x_train,y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
# sv3=SVC(kernel="precomputed") 
sv3=SVC(kernel="rbf") ## rbf= radial basic function
sv3.fit(x_train,y_train)
# Out:
# SVC()

# %%
print("Testing Score")
print("linear",sv.score(x_test,y_test)*100)
print("poly",sv1.score(x_test,y_test)*100)
print("sigmoid",sv2.score(x_test,y_test)*100)
print("rbf",sv3.score(x_test,y_test)*100)
# Out:
# Testing Score
# linear 50.5
# poly 50.5
# sigmoid 55.00000000000001
# rbf 51.0

# %%
print("Training Score")
print("linear",sv.score(x_train,y_train)*100)
print("poly",sv1.score(x_train,y_train)*100)
print("sigmoid",sv2.score(x_train,y_train)*100)
print("rbf",sv3.score(x_train,y_train)*100)
# Out:
# Training Score
# linear 51.24999999999999
# poly 51.24999999999999
# sigmoid 48.0
# rbf 51.74999999999999

# %% [markdown]
# # Hence the best kernel will be "RBF"

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=sv1)
plt.show()
# Out:
# F:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=sv2)
plt.show()
# Out:
# F:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=sv3)
plt.show()
# Out:
# F:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
