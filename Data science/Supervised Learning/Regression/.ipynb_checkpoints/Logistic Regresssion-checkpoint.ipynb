# %% [markdown]
# # Binary Classification

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../../../data/Social_Network_Ads.csv")
df.head(5)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %% [markdown]
# ## For Single Input

# %%
df.drop(columns={"EstimatedSalary"},inplace=True)
df.head(3)
# Out:
#    Age  Purchased
# 0   19          0
# 1   35          0
# 2   26          0

# %%
plt.figure(figsize=(7,3))
sns.scatterplot(x="Age",y="Purchased",data=df)
plt.show()

# %%
x=df[["Age"]]
y=df[["Purchased"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# F:\python\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 91.25

# %%
lr.predict([[60]])
# Out:
# F:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
plt.figure(figsize=(7,3))
sns.scatterplot(x="Age",y="Purchased",data=df)
sns.lineplot(x="Age",y=lr.predict(x),data=df,color="red")
plt.show()

# %% [markdown]
# ## For Multiple Input

# %%
mdf=pd.read_csv("../../../data/placement_update.csv")
mdf.head(3)
# Out:
#    cgpa  score  placed
# 0  7.19     26       1
# 1  7.46     38       1
# 2  7.54     40       1

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="cgpa",y="score",data=mdf,hue="placed")
plt.show()

# %% [markdown]
# ### It is not linearly seperated but we use it for learn

# %%
x=mdf.iloc[:,:-1]
# x.ndim
y=mdf["placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 54.0

# %%
lr.predict([[7.19,26]])
# Out:
# F:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
plt.show()
# Out:
# F:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
