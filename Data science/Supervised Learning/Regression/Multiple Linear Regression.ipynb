# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("../../../data/salary_Data.csv")
df.head(3)
# Out:
#     Age  Experience  Salary
# 0  21.0         1.1   39343
# 1  21.5         1.3   46205
# 2  21.7         1.5   37731

# %%
df.shape
# Out:
# (30, 3)

# %%
df.isnull().sum()
# Out:
# Age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.pairplot(df)
plt.show()

# %%
sns.heatmap(data=df.corr(),annot=True)
plt.show()

# %%
x=df.iloc[:,:-1]
y=df[["Salary"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x.ndim,y.ndim
# Out:
# (2, 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 88.52101657216537

# %%
lr.predict([[21,1.1]])
# Out:
# F:\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[38675.56314937]])

# %% [markdown]
# ### By Formula

# %% [markdown]
# y=m1x1+m2x2+...+c

# %%
lr.coef_ ## value of m
# Out:
# array([[2567.51865301, 4882.14850701]])

# %%
lr.intercept_ ## value of c
# Out:
# array([-20612.69192149])

# %%
## y_prd=2567.51865301*Age+(4882.14850701*Experience)+(-20612.69192149)

# %%
 y_prd=2567.51865301*(21)+(4882.14850701*(1.1))+(-20612.69192149)
y_prd
# Out:
# 38675.56314943101
