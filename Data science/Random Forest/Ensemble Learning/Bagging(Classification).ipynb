# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
import seaborn as sns

# %%
x,y=make_moons(n_samples=500,noise=0.2)

# %%
df={"x1":x[:,0],"x2":x[:,1],"y":y}

# %%
dataset=pd.DataFrame(df)

# %%
dataset
# Out:
#            x1        x2  y
# 0    2.133116 -0.142374  1
# 1    1.104359 -0.217088  1
# 2    1.186448  0.029347  0
# 3    0.791156  0.738833  0
# 4    1.981695 -0.154451  1
# ..        ...       ... ..
# 495  0.549249  0.951937  0
# 496  2.216283  0.406008  1
# 497  0.856965 -0.722576  1
# 498  0.329869  1.045111  0
# 499 -0.302003  1.003285  0
#
# [500 rows x 3 columns]

# %%
sns.scatterplot(x="x1",y="x2",data=dataset,hue=y)
plt.show()

# %%
x_a=dataset.iloc[:,:-1]
y_a=dataset["y"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_a,y_a,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
sv=SVC()
sv.fit(x_train,y_train)
sv.score(x_train,y_train)*100,sv.score(x_test,y_test)*100
# Out:
# (97.0, 98.0)

# %%
bg=BaggingClassifier(estimator=SVC(),n_estimators=50)
bg.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=SVC(), n_estimators=50)

# %%
bg.score(x_train,y_train)*100,bg.score(x_test,y_test)*100
# Out:
# (97.5, 98.0)

# %% [markdown]
# ### Random Forest

# %%
rf=RandomForestClassifier(n_estimators=30)
rf.fit(x_train,y_train)
rf.score(x_train,y_train)*100,rf.score(x_test,y_test)*100
# Out:
# (99.75, 97.0)
