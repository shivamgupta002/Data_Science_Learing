# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons

# %%
x,y=make_moons(n_samples=250,noise=0.05)

# %%
d={"data1":x[:,0],"data2":x[:,1]}
df=pd.DataFrame(d)

# %%
df.head(3)
# Out:
#       data1     data2
# 0  0.803119  0.632570
# 1  1.373310 -0.307633
# 2 -0.638559  0.697682

# %%
sns.scatterplot(x="data1",y="data2",data=df)
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
db=DBSCAN(eps=0.2,min_samples=5)
df["predict"]=db.fit_predict(df)

# %%
df.head(3)
# Out:
#       data1     data2  predict
# 0  0.803119  0.632570        0
# 1  1.373310 -0.307633        1
# 2 -0.638559  0.697682        0

# %%
sns.scatterplot(x="data1",y="data2",data=df,hue="predict")
plt.show()

# %% [markdown]
# ### For cross Check create data d1

# %%
d1={"data1":x[:,0],"data2":x[:,1],"output":y}
df1=pd.DataFrame(d1)

# %%
df1.head(3)
# Out:
#       data1     data2  output
# 0  0.803119  0.632570       0
# 1  1.373310 -0.307633       1
# 2 -0.638559  0.697682       0

# %%
sns.scatterplot(x="data1",y="data2",data=df1,hue="output")
plt.show()
