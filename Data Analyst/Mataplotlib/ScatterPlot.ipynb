# %%
# A scatter plot is a chart that display the realtionship between 2 varibale. A dot represnts each value in the data set

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data
# Score of 2 team
team1_score=[25,14,85,35,54,8,87,97]
team2_score=[92,43,93,21,4,75,22,85]

# score range of tailenders(lower order bottom)in cricket
scoreRange=[5,10,15,20,25,30,35,40]

# %%
# Plot a scatter plot using pyplot.scatter() method
plt.scatter(team1_score,scoreRange,color='r')
plt.scatter(team2_score,scoreRange,color='b')

# Set Lables
plt.xlabel("Team Score")
plt.ylabel("Score Range")

# Plot Title
plt.title("Score of two teams")
# Out:
# Text(0.5, 1.0, 'Score of two teams')
