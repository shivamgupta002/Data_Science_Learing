# %% [markdown]
# # Count Plot

# %% [markdown]
# ## Differnce between countPlot and bar plot

# %%
# Countplot plots the count of the number of records by category
# Barplot plots a value or metric for each category (bydefault, barplot plots the mean of a variable, by category)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
var=sns.load_dataset("tips")
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x="sex",y="size",data=var)
plt.show()

# %%
sns.countplot(x="sex",data=var)
plt.show()

# %%
sns.countplot(x="sex",data=var,hue="smoker",palette="Accent")
plt.show()

# %%
sns.countplot(x="sex",data=var,hue="smoker",color="blue")
plt.show()
# Out:
# C:\Users\SHIVAM\AppData\Local\Temp\ipykernel_9964\1346256287.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:blue'` for the same effect.
#
#   sns.countplot(x="sex",data=var,hue="smoker",color="blue")

# %%
sns.countplot(x="sex",data=var,hue="smoker",saturation=0.3)
plt.show()

# %%
# order / hue_order: Specifies the order of categories for x/y or hue.
# orient: 'v' for vertical bars, 'h' for horizontal.
# color: Single color for all bars.
# palette: Set of colors for bars (e.g., 'pastel', 'deep').
# saturation: Adjusts bar color intensity (default: 0.75).
# fill: Whether bars are filled (True by default).
# hue_norm: Normalizes the hue values for color mapping.
# stat: Statistic to compute ('count' by default, can be 'percent').
# width: Width of bars (default: 0.8).
# dodge: Separates bars for different hue levels (default: 'auto').
# gap: Adds space between bars (default: 0).
# log_scale: Logarithmic scaling for axes (default: None).
# native_scale: Retains the original scale of data if True.
# formatter: Formatter for the axis labels.
# legend: Displays legend automatically ('auto'), or turn off with False.
# ax: Matplotlib Axes to draw on (if not provided, creates a new one).
# kwargs: Additional parameters for customization
